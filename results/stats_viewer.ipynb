# %%
load_ext autoreload

# %%
autoreload 2

# %%
from factorlib.statistics import Statistics
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
stats = Statistics()
stats.load('wfo_stats.pkl')
stats.print_statistics_report()
# Out:
# Empty Statistics object created. Load object using load(path: str) method.
#
# FACTOR MODEL ANALYSIS REPORT
# ...
# Relative to baseline models:
# Spearman correlation: -0.013949992408044768
# +--------------+---------+--------+----------+---------+
# |   metric:    | factors |  spy   | buy_hold |  random |
# +--------------+---------+--------+----------+---------+
# | cum. returns |  32.46% | 31.22% |  33.87%  |  -20.8% |
# |    sharpe    |  2.506  | 2.233  |  2.307   |  -1.816 |
# |   sortino    |  3.703  | 3.251  |  3.373   |  -2.481 |
# |     cagr     |  32.67% | 31.42% |  34.08%  |  -20.9% |
# |  avg rtrns   |  0.11%  | 0.11%  |  0.12%   |  -0.09% |
# | max drawdown |  -5.92% | -6.62% |  -6.84%  | -22.61% |
# |  volatility  |  11.52% | 12.56% |  13.05%  |  12.45% |
# |   win rate   |  59.92% | 59.52% |  59.92%  |  41.04% |
# +--------------+---------+--------+----------+---------+

# %%
stats.compute_correlations()
# Out:
# <style type="text/css">
# #T_f41b5_row0_col0, #T_f41b5_row1_col1, #T_f41b5_row2_col2, #T_f41b5_row3_col3, #T_f41b5_row4_col4, #T_f41b5_row5_col5, #T_f41b5_row6_col6, #T_f41b5_row7_col7, #T_f41b5_row8_col8, #T_f41b5_row9_col9, #T_f41b5_row10_col10, #T_f41b5_row10_col11, #T_f41b5_row11_col10, #T_f41b5_row11_col11, #T_f41b5_row12_col12, #T_f41b5_row13_col13, #T_f41b5_row14_col14, #T_f41b5_row15_col15, #T_f41b5_row16_col16, #T_f41b5_row17_col17, #T_f41b5_row18_col18, #T_f41b5_row19_col19, #T_f41b5_row20_col20, #T_f41b5_row21_col21, #T_f41b5_row22_col22, #T_f41b5_row23_col23, #T_f41b5_row24_col24, #T_f41b5_row25_col25, #T_f41b5_row26_col26, #T_f41b5_row27_col27, #T_f41b5_row28_col28, #T_f41b5_row29_col29, #T_f41b5_row30_col30, #T_f41b5_row31_col31, #T_f41b5_row32_col32, #T_f41b5_row33_col33, #T_f41b5_row34_col34, #T_f41b5_row35_col35, #T_f41b5_row36_col36, #T_f41b5_row37_col37, #T_f41b5_row38_col38, #T_f41b5_row39_col39, #T_f41b5_row40_col40, #T_f41b5_row41_col41 {
# ...

# %%
stats.get_factor_names()
# Out:
# Mkt-RF_None
# SMB_None
# HML_None
# RMW_None
# CMA_None
# RF_None
# log_prices_logged
# BND_index
# GDX_index
# QQQ_index
# TLT_index
# TMF_index
# VIX_index
# WTI_index
# returns_shifted_20
# returns_shifted_1
# returns_shifted_7
# vols_volatility60
# sma_3_sma3
# sma_6_sma6_momentum1
# sma_12_sma12_momentum1
# sma_30_sma30_momentum1
# PEG_1yrforward
# aftret_invcapx
# bm
# capital_ratio
# curr_ratio
# gpm
# pcf
# pe_op_dil
# ptb
# quick_ratio
# roa
# roe
# momentum_60_momentum60
# momentum_10_momentum10
# momentum_30_momentum30
# candle
# prev_candle
# prev_prev_candle
# GDPC1_CPIAUCSL_gdp_cpi_ratio
# UN/CPI_unemployment_cpi_ratio

# %%
stats.plot_beeswarm_shaps()
